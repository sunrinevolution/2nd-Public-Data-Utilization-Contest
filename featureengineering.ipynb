# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
gr_vote = pd.read_csv('/content/drive/My Drive/Project/Library Book Reservation Prediction/vote_preprocessed/vote_guro.csv')
guro_book_loan = pd.read_csv('/content/drive/My Drive/Project/Library Book Reservation Prediction/preprocessed_data/preprocessed_guro.csv')

# %%
guro_book_loan['대출일'] = pd.to_datetime(guro_book_loan['대출일'], format='%Y-%m-%d', errors='raise')
